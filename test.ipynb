# %%
import module as m

# %%
m.createRecord("buveidcevj",["yveuiwo","uewmdq","urieovie"],8,"urieop","high")
# Out:
#   medication_name         active_ingredients  dosage_frequency_in_hours  \
# 0      buveidcevj  yveuiwo, uewmdq, urieovie                          8
#
#   Usage_and_Safety_Instructions Urgency
# 0                        urieop    high
